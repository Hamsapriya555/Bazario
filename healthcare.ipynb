# %% [markdown]
# <a href="https://colab.research.google.com/github/Hamsapriya555/Bazario/blob/main/healthcare.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q transformers datasets accelerate peft bitsandbytes
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.9/73.9 kB 3.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 494.8/494.8 kB 13.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 472.3/472.3 kB 25.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.9/72.9 MB 16.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 8.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 193.6/193.6 kB 14.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.5/143.5 kB 11.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.8/194.8 kB 14.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 65.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 235.3/235.3 kB 18.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 213.5/213.5 kB 14.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 349.0/349.0 kB 22.1 MB/s eta 0:00:00

# %%
import json
from datasets import Dataset

# Load JSON file
with open("healthcare_data.json", "r") as f:
    data = json.load(f)

# Convert to Hugging Face Dataset
dataset = Dataset.from_list(data)

# Split into train and test sets
dataset = dataset.train_test_split(test_size=0.2)

# Preview
dataset
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['prompt', 'response'],
#         num_rows: 20
#     })
#     test: Dataset({
#         features: ['prompt', 'response'],
#         num_rows: 5
#     })
# })

# %%
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM

model_name = "google/flan-t5-base"

# Load tokenizer and model
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForSeq2SeqLM.from_pretrained(model_name)
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# spiece.model:   0%|          | 0.00/792k [00:00<?, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json: 0.00B [00:00, ?B/s]
# config.json: 0.00B [00:00, ?B/s]
# model.safetensors:   0%|          | 0.00/990M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/147 [00:00<?, ?B/s]

# %%
def preprocess(example):
    input_text = example["prompt"]
    target_text = example["response"]

    model_inputs = tokenizer(
        input_text,
        max_length=256,
        padding="max_length",
        truncation=True
    )

    labels = tokenizer(
        target_text,
        max_length=256,
        padding="max_length",
        truncation=True
    )

    model_inputs["labels"] = labels["input_ids"]
    return model_inputs

tokenized_dataset = dataset.map(preprocess, remove_columns=["prompt", "response"])
# Out:
# ...
# Map:   0%|          | 0/5 [00:00<?, ? examples/s]

# %%
# !pip install -U transformers
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.7/41.7 kB 1.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.2/11.2 MB 74.1 MB/s eta 0:00:00
# ...
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.54.0
#     Uninstalling transformers-4.54.0:
#       Successfully uninstalled transformers-4.54.0
# ...

# %%
from transformers import AutoModelForSeq2SeqLM, AutoTokenizer

model_name = "google/flan-t5-base"
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForSeq2SeqLM.from_pretrained(model_name)
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(

# %%
from datasets import load_dataset

dataset = load_dataset("json", data_files="healthcare_data.json")["train"]
# Out:
# Generating train split: 0 examples [00:00, ? examples/s]

# %%
from transformers import TrainingArguments, Trainer

training_args = TrainingArguments(
    output_dir="./flan-t5-healthcare-model",
    learning_rate=2e-5,
    per_device_train_batch_size=4,
    num_train_epochs=3,
    weight_decay=0.01,
    save_total_limit=1,
    logging_steps=10,
    save_steps=500,  # instead of save_strategy
    save_on_each_node=False,
    do_train=True
)

trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=tokenized_dataset
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-4019661086.py in <cell line: 0>()
#      17     model=model,
#      18     args=training_args,
# ---> 19     train_dataset=tokenized_dataset
#      20 )
#
# NameError: name 'tokenized_dataset' is not defined

# %%
def preprocess(example):
    input_text = example["prompt"]
    target_text = example["response"]

    model_inputs = tokenizer(
        input_text,
        max_length=256,
        padding="max_length",
        truncation=True
    )

    labels = tokenizer(
        target_text,
        max_length=256,
        padding="max_length",
        truncation=True
    )

    model_inputs["labels"] = labels["input_ids"]
    return model_inputs

tokenized_dataset = dataset.map(preprocess, remove_columns=["prompt", "response"])

# %%
from transformers import TrainingArguments, Trainer

training_args = TrainingArguments(
    output_dir="./flan-t5-healthcare-model",
    learning_rate=2e-5,
    per_device_train_batch_size=4,
    num_train_epochs=3,
    weight_decay=0.01,
    save_total_limit=1,
    logging_steps=10,
    save_steps=500,  # instead of save_strategy
    save_on_each_node=False,
    do_train=True
)

trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=tokenized_dataset
)

# %%
trainer.train()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-49973641.py in <cell line: 0>()
# ----> 1 trainer.train()
#
# NameError: name 'trainer' is not defined

# %%
from transformers import TrainingArguments, Trainer

training_args = TrainingArguments(
    output_dir="./flan-t5-healthcare-model",
    learning_rate=2e-5,
    per_device_train_batch_size=4,
    num_train_epochs=3,
    weight_decay=0.01,
    save_total_limit=1,
    logging_steps=10,
    save_steps=500,  # instead of save_strategy
    save_on_each_node=False,
    do_train=True
)

trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=tokenized_dataset
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1003778316.py in <cell line: 0>()
#      17     model=model,
#      18     args=training_args,
# ---> 19     train_dataset=tokenized_dataset
#      20 )
#
# NameError: name 'tokenized_dataset' is not defined

# %%
trainer.train()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-4032920361.py in <cell line: 0>()
# ----> 1 trainer.train()
#
# NameError: name 'trainer' is not defined

# %%
def preprocess(example):
    input_text = example["prompt"]
    target_text = example["response"]

    model_inputs = tokenizer(
        input_text,
        max_length=256,
        padding="max_length",
        truncation=True
    )

    labels = tokenizer(
        target_text,
        max_length=256,
        padding="max_length",
        truncation=True
    )

    model_inputs["labels"] = labels["input_ids"]
    return model_inputs

tokenized_dataset = dataset.map(preprocess, remove_columns=["prompt", "response"])
# Out:
# Map:   0%|          | 0/25 [00:00<?, ? examples/s]

# %%
from transformers import TrainingArguments, Trainer

training_args = TrainingArguments(
    output_dir="./flan-t5-healthcare-model",
    learning_rate=2e-5,
    per_device_train_batch_size=4,
    num_train_epochs=1,  # 👈 ONLY THIS CHANGED
    weight_decay=0.01,
    save_total_limit=1,
    logging_steps=10,
    save_steps=500,
    save_on_each_node=False,
    do_train=True
)

trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=tokenized_dataset
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3709942685.py in <cell line: 0>()
#      15
#      16 trainer = Trainer(
# ---> 17     model=model,
#      18     args=training_args,
#      19     train_dataset=tokenized_dataset
#
# NameError: name 'model' is not defined

# %%
trainer.train()
# Out:
#     <div>
#
#       <progress value='2' max='3' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [2/3 : < :, Epoch 1/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>

# %%
from transformers import AutoModelForSeq2SeqLM, AutoTokenizer

model_name = "google/flan-t5-base"
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForSeq2SeqLM.from_pretrained(model_name)
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(

# %%
from transformers import TrainingArguments, Trainer

training_args = TrainingArguments(
    output_dir="./flan-t5-healthcare-model",
    learning_rate=2e-5,
    per_device_train_batch_size=4,
    num_train_epochs=1,
    weight_decay=0.01,
    save_total_limit=1,
    logging_steps=10,
    save_steps=500,
    save_on_each_node=False,
    do_train=True
)

trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=tokenized_dataset
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-315666574.py in <cell line: 0>()
#      17     model=model,
#      18     args=training_args,
# ---> 19     train_dataset=tokenized_dataset
#      20 )
#
# NameError: name 'tokenized_dataset' is not defined

# %%
def preprocess(example):
    input_text = example["prompt"]
    target_text = example["response"]

    model_inputs = tokenizer(
        input_text,
        max_length=256,
        padding="max_length",
        truncation=True
    )

    labels = tokenizer(
        target_text,
        max_length=256,
        padding="max_length",
        truncation=True
    )

    model_inputs["labels"] = labels["input_ids"]
    return model_inputs

tokenized_dataset = dataset.map(preprocess, remove_columns=["prompt", "response"])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3903289572.py in <cell line: 0>()
#      20     return model_inputs
#      21
# ---> 22 tokenized_dataset = dataset.map(preprocess, remove_columns=["prompt", "response"])
#
# NameError: name 'dataset' is not defined

# %%
trainer.train()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-4032920361.py in <cell line: 0>()
# ----> 1 trainer.train()
#
# NameError: name 'trainer' is not defined

# %%
from datasets import load_dataset

dataset = load_dataset("json", data_files="healthcare_data.json")["train"]

# %%
def preprocess(example):
    input_text = example["prompt"]
    target_text = example["response"]

    model_inputs = tokenizer(
        input_text,
        max_length=256,
        padding="max_length",
        truncation=True
    )

    labels = tokenizer(
        target_text,
        max_length=256,
        padding="max_length",
        truncation=True
    )

    model_inputs["labels"] = labels["input_ids"]
    return model_inputs

tokenized_dataset = dataset.map(preprocess, remove_columns=["prompt", "response"])

# %%
from transformers import TrainingArguments, Trainer

training_args = TrainingArguments(
    output_dir="./flan-t5-healthcare-model",
    learning_rate=2e-5,
    per_device_train_batch_size=4,
    num_train_epochs=1,
    weight_decay=0.01,
    # save_total_limit=1, # Removed save limit
    logging_steps=10,
    save_strategy="epoch",  # Changed save_steps to save_strategy and set to "epoch"
    save_on_each_node=False,
    do_train=True
)

trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=tokenized_dataset
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1356793160.py in <cell line: 0>()
#      15
#      16 trainer = Trainer(
# ---> 17     model=model,
#      18     args=training_args,
#      19     train_dataset=tokenized_dataset
#
# NameError: name 'model' is not defined

# %%
trainer.train()
# Out:
#     <div>
#
#       <progress value='2' max='1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [2/1 : < :, Epoch 1/1]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>

# %%
from pathlib import Path
print(list(Path("./flan-t5-healthcare-model").glob("**/*")))
# Out:
# [PosixPath('flan-t5-healthcare-model/checkpoint-1'), PosixPath('flan-t5-healthcare-model/checkpoint-1/training_args.bin')]

# %%
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM

# Use original model name here (used during training)
base_model = "google/flan-t5-small"  # or flan-t5-base if you used that

tokenizer = AutoTokenizer.from_pretrained(base_model)
model = AutoModelForSeq2SeqLM.from_pretrained("./flan-t5-healthcare-model/checkpoint-1")
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# spiece.model:   0%|          | 0.00/792k [00:00<?, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json: 0.00B [00:00, ?B/s]
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# /tmp/ipython-input-977026745.py in <cell line: 0>()
#       5
# ...

# %%
from pathlib import Path
print(list(Path("./flan-t5-healthcare-model").glob("**/checkpoint-*")))
# Out:
# [PosixPath('flan-t5-healthcare-model/checkpoint-1')]

# %%
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM

# Load tokenizer from base model (not from checkpoint)
tokenizer = AutoTokenizer.from_pretrained("google/flan-t5-base")

# Load trained weights from your checkpoint
model = AutoModelForSeq2SeqLM.from_pretrained("./flan-t5-healthcare-model/checkpoint-1", local_files_only=True)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# /tmp/ipython-input-1658322757.py in <cell line: 0>()
#       5
#       6 # Load trained weights from your checkpoint
# ----> 7 model = AutoModelForSeq2SeqLM.from_pretrained("./flan-t5-healthcare-model/checkpoint-1", local_files_only=True)
#
# /usr/local/lib/python3.11/dist-packages/transformers/models/auto/auto_factory.py in from_pretrained(cls, pretrained_model_name_or_path, *model_args, **kwargs)
#     598             if model_class.config_class == config.sub_configs.get("text_config", None):
#     599                 config = config.get_text_config()
# --> 600             return model_class.from_pretrained(
#     601                 pretrained_model_name_or_path, *model_args, config=config, **hub_kwargs, **kwargs
#     602             )
#
# ...

# %%
inputs = tokenizer("What are the symptoms of diabetes?", return_tensors="pt")
outputs = model.generate(**inputs, max_length=100)
print(tokenizer.decode(outputs[0], skip_special_tokens=True))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-2038077959.py in <cell line: 0>()
#       1 inputs = tokenizer("What are the symptoms of diabetes?", return_tensors="pt")
# ----> 2 outputs = model.generate(**inputs, max_length=100)
#       3 print(tokenizer.decode(outputs[0], skip_special_tokens=True))
#
# NameError: name 'model' is not defined

# %%
from pathlib import Path
print(list(Path("./flan-t5-healthcare-model").glob("**/checkpoint-*")))
# Out:
# [PosixPath('flan-t5-healthcare-model/checkpoint-1')]

# %%
from transformers import AutoModelForSeq2SeqLM, AutoTokenizer

model_name = "google/flan-t5-base"
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForSeq2SeqLM.from_pretrained(model_name)

# %%
from transformers import TrainingArguments, Trainer

training_args = TrainingArguments(
    output_dir="./flan-t5-healthcare-model",
    learning_rate=2e-5,
    per_device_train_batch_size=4,
    num_train_epochs=1,
    weight_decay=0.01,
    # save_total_limit=1, # Removed save limit
    logging_steps=10,
    save_strategy="epoch",  # Changed save_steps to save_strategy and set to "epoch"
    save_on_each_node=False,
    do_train=True
)

trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=tokenized_dataset
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1356793160.py in <cell line: 0>()
#      17     model=model,
#      18     args=training_args,
# ---> 19     train_dataset=tokenized_dataset
#      20 )
#
# NameError: name 'tokenized_dataset' is not defined

# %%
def preprocess(example):
    input_text = example["prompt"]
    target_text = example["response"]

    model_inputs = tokenizer(
        input_text,
        max_length=256,
        padding="max_length",
        truncation=True
    )

    labels = tokenizer(
        target_text,
        max_length=256,
        padding="max_length",
        truncation=True
    )

    model_inputs["labels"] = labels["input_ids"]
    return model_inputs

tokenized_dataset = dataset.map(preprocess, remove_columns=["prompt", "response"])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3903289572.py in <cell line: 0>()
#      20     return model_inputs
#      21
# ---> 22 tokenized_dataset = dataset.map(preprocess, remove_columns=["prompt", "response"])
#
# NameError: name 'dataset' is not defined

# %%
from transformers import TrainingArguments, Trainer

training_args = TrainingArguments(
    output_dir="./flan-t5-healthcare-model",
    learning_rate=2e-5,
    per_device_train_batch_size=4,
    num_train_epochs=1,
    weight_decay=0.01,
    # save_total_limit=1, # Removed save limit
    logging_steps=10,
    save_strategy="epoch",  # Changed save_steps to save_strategy and set to "epoch"
    save_on_each_node=False,
    do_train=True
)

trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=tokenized_dataset
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1356793160.py in <cell line: 0>()
#      17     model=model,
#      18     args=training_args,
# ---> 19     train_dataset=tokenized_dataset
#      20 )
#
# NameError: name 'tokenized_dataset' is not defined

# %%
trainer.train()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-4032920361.py in <cell line: 0>()
# ----> 1 trainer.train()
#
# NameError: name 'trainer' is not defined

# %%
from datasets import load_dataset

dataset = load_dataset("json", data_files="healthcare_data.json")["train"]

# %%
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM

model_name = "google/flan-t5-base"
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForSeq2SeqLM.from_pretrained(model_name)

# %%
def preprocess(example):
    input_text = example["prompt"]
    target_text = example["response"]

    model_inputs = tokenizer(
        input_text,
        max_length=256,
        padding="max_length",
        truncation=True
    )

    labels = tokenizer(
        target_text,
        max_length=256,
        padding="max_length",
        truncation=True
    )

    model_inputs["labels"] = labels["input_ids"]
    return model_inputs

tokenized_dataset = dataset.map(preprocess, remove_columns=["prompt", "response"])

# %%
from transformers import TrainingArguments, Trainer

training_args = TrainingArguments(
    output_dir="./flan-t5-healthcare-model",
    learning_rate=2e-5,
    per_device_train_batch_size=4,
    num_train_epochs=1,
    weight_decay=0.01,
    # save_total_limit=1, # Removed save limit
    logging_steps=10,
    save_strategy="epoch",  # Changed save_steps to save_strategy and set to "epoch"
    save_on_each_node=False,
    do_train=True
)

trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=tokenized_dataset
)

# %%
trainer.train()

# %%
from transformers import TrainingArguments, Trainer

training_args = TrainingArguments(
    output_dir="./flan-t5-healthcare-model",
    learning_rate=2e-5,
    per_device_train_batch_size=4,
    num_train_epochs=1,
    weight_decay=0.01,
    logging_steps=10,
    save_steps=10,
    save_on_each_node=False,
    do_train=True
)

trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=tokenized_dataset
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-878497308.py in <cell line: 0>()
#      16     model=model,
#      17     args=training_args,
# ---> 18     train_dataset=tokenized_dataset
#      19 )
#
# NameError: name 'tokenized_dataset' is not defined

# %%
from datasets import Dataset

dataset = Dataset.from_list(data)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-4193762613.py in <cell line: 0>()
#       1 from datasets import Dataset
#       2
# ----> 3 dataset = Dataset.from_list(data)
#
# NameError: name 'data' is not defined
